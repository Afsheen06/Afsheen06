# %% [markdown]
# <a href="https://colab.research.google.com/github/Afsheen06/Afsheen06/blob/main/python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Codefobe")
# Out:
# Hello Codefobe

# %%
print("Name:Afsheen M")
print("Place: Trichy")
print("Emoji: ")
print("Why I joined:Because I wanted to excel in python")
# Out:
# Name:Afsheen M
# Place: Trichy
# Emoji:
# Why I joined:Because I wanted to excel in python

# %%
print("Welcome to Python Bootcamp with AI Internship! 👋\nLet’s build something awesome together 💻🚀")
# Out:
# Welcome to Python Bootcamp with AI Internship! 👋
# Let’s build something awesome together 💻🚀

# %%
""" Planning a weekend Trip
Step 1:Gather Friends
Step 2: Pick a place.
Step 3: List of spots to visit
Step 4: Book transport """

#Step 1
friends = "joe,aash,sana,saam"
#step 2
place = "Paris"
#step 3
spots = "Eiffel Tower, Louvre Museum, Notre-Dame Cathedral"
#step 4
transport = "Car"

print(f"We {friends} are going on a weekend trip to {place}.The spots we are visiting are {spots} and we have planned to travel through {transport}.")
# Out:
# We joe,aash,sana,saam are going on a weekend trip to Paris.The spots we are visiting are Eiffel Tower, Louvre Museum, Notre-Dame Cathedral and we have planned to travel through Car.

# %%
# Step 1: Write down guest name
# Step 2: Write the event details
# Step 3: Send the invitation

guest_name = "Ayesha"
event = "Birthday Party"
location = "Wonderland Cafe"
time = "5:00 PM"

print(f"Dear {guest_name}, you're invited to my {event} at {location} at {time}.")
# Out:
# Dear Ayesha, you're invited to my Birthday Party at Wonderland Cafe at 5:00 PM.

# %%
'''Visiting a food delivery app
Browsing menu
Selecting a dish
Making payment
Waiting for delivery'''

#Step 1: Visiting a food delivery app
print("Open the food delivery app...")
#Step 2: Browsing menu
print("Searching the menu for food")
#Step 3: Selecting Dish
print("Biriyani")
#Step 4: Making payment
print("UPI")
#Step 5: Waiting for delivery
print("Order picked ")
# Out:
# Order picked
# Open the food delivery app...
# Searching the menu for food
# Biriyani
# UPI

# %%
name = input()
age = input()
address = input()
print("My name is:",name)
print("My age is:", age)
print("My Address is:", address)
# Out:
# afsheen
# 20
# trichy tamilnadu
# My name is: afsheen
# My age is: 20
# My Address is: trichy tamilnadu

# %% [markdown]
# a=int(input())
# b=int(input())
# c=int(input())
# d=(a*b*c)
# e=(a+b+c)
# f=(d/e)
# print(f)

# %%
name = input()
score = int(input())
dept = input()
print("My name is:",name)
print("My score is:",score/10)
print("My dept is:",dept)
# Out:
# Afsheen
# 95
# AIML
# My name is: Afsheen
# My score is: 9.5
# My dept is: AIML

# %%
meghana = input()
if(meghana == "died"):
  print("surya meets priya")
else:
  print("surya weds meghana")
# Out:
# died
# surya meets priya

# %%
marks = int(input())
if (marks>34):
  print("Passed")
else:
  print("Failed")
# Out:
# 35
# Passed

# %%
income = int(input("income:"))
if(income > 7000):
  print("Scholarship Available")
else:
  print("No scholarship available")
# Out:
# income:60000
# Scholarship Available

# %%
a=int(input())
if(a%3==0 and a%5==0):
  print("Divisible by 3 and 5")
else:
  print("Not divisible by 3 and 5")
# Out:
# 15
# Divisible by 3 and 5

# %%
 a=int(input("Enter a number:"))
 if (a%2==0):
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number:3
# Odd

# %%
score = int(input("Score:"))
if(score<=35):
  print("Poor student")
if(score > 35 and score<= 70):
  print("Average student")
if(score > 70):
  print("Good student")
# Out:
# Score:70
# Average student

# %%
score = int(input("Score:"))
if(score<=35):
  print("Poor student")
elif(score > 35 and score<= 70):
  print("Average student")
elif(score > 70 and score < 100):
  print("Good student")
else:
  print("Invalid")
# Out:
# Score:999
# Invalid

# %%
#Mini calc
a = int(input("A:"))
b = int(input("B:"))
operation=input("add/sub/mul/div:")
if(operation == "add"):
  print(a+b)
elif(operation == "sub"):
  print(a-b)
elif(operation == "mul"):
  print(a*b)
elif(operation == "div"):
  print(a/b)
# Out:
# A:5
# B:5
# add/sub/mul/div:add
# 10

# %%
score = int(input("Score %:"))
if(score > 69):
  name = input("Name:")
  dept = input("Dept:")
  loc = input("Loc:")
  print("You are Eligible")
else:
  print("You are not eligible")
# Out:
# Score %:70
# Name:afsheen
# Dept:aiml
# Loc:trichy
# You are Eligible

# %%
salary = int(input("Salary:"))
age = int(input("Age:"))
if(salary >= 20000) or (age <= 25):
  loan = int(input("Required loan amt:"))
  if(loan <= 50000):
    print("You are eligible for loan")
  elif(loan > 50000):
    print("Maximum loan amt is 50000")
# Out:
# Salary:8000
# Age:7
