# %% [markdown]
# <a href="https://colab.research.google.com/github/Afsheen06/Afsheen06/blob/main/Assignment_1_Afsheen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
Bal = int(input("Current Balance:"))
withdrawal = int(input("Withdrawl Amount:"))
if withdrawal%100 == 0 and withdrawal<= Bal and (Bal - withdrawal)>=500:
  print("Transaction Approved")
  print(f"Remaining Balance:Rs.{Bal - withdrawal}")
else:
  print("Transaction denied")
# Out:
# Current Balance:20000
# Withdrawl Amount:7000
# Transaction Approved
# Remaining Balance:Rs.13000

# %%
#2
tax = int(input("Income:"))
if(tax==250000):
  print("No tax")
elif(tax>250000):
  print("5% Tax Applied")
elif(tax==500000):
  print("20% Tax Applied")
#Above= 30%
else:
  print("30% Tax Applied")
# Out:
# Income:270000
# 5% Tax Applied

# %%
#3
n = int(input("Enter Number:"))
a = n // 10
b = n % 10
sum = a+b
prod = a*b
if(sum % 2 == 0 and prod % 3 == 0):
  print("Stable")
else:
  print("Not Stable")
# Out:
# Enter Number:66
# Stable

# %%
#4
password = "admin123"

p1=input("Enter Password:")
if(p1==password):
  print("Login Successful")
else:
  p2=input("Enter Password:")
  if(p2==password):
    print("Login Successful")
  else:
    p3=input("Enter Password:")
    if(p3==password):
      print("Login Successful")
    else:
      print("Account Locked")
# Out:
# Enter Password:jefnwoiej
# Enter Password:wieno
# Enter Password:ewiwbcwu9
# Account Locked

# %%
#5
distance = int(input("Enter Distance:"))
if distance <=5:
  fare = 50 + distance * 10
elif distance <= 15:
  fare = 50 + 5 * 10 + (distance - 5) * 8
else:
  fare = 50 + 5 * 10 + 10 * 8 + (distance - 15) * 5
print("Total fare:",fare)
# Out:
# Enter Distance:7
# Total fare: 116

# %%
#6
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a + b > c and a + c > b and b + c > a:
    if a == b and b == c:
        print("Equilateral")
    elif a == b or b == c or a == c:
        print("Isosceles")
    else:
        print("Scalene")
else:
    print("Invalid Triangle")
# Out:
# Enter first side: 77
# Enter second side: 83
# Enter third side: 42
# Scalene

# %%
#7
units = int(input("Enter units: "))
bill = float(input("Enter bill amount: "))

if units > 500:
    bill = bill + (bill * 15 / 100)
elif units > 300 and bill >= 2000:
    bill = bill + (bill * 10 / 100)

print("Final Bill =", bill)
# Out:
# Enter units: 700
# Enter bill amount: 3000
# Final Bill = 3450.0

# %%
#8
attendance = int(input("Enter attendance (%): "))
medical = input("Medical condition (True/False): ")

if attendance >= 75 or medical == "True":
    print("Eligible for Exam")
else:
    print("Not Eligible")
# Out:
# Enter attendance (%): 77
# Medical condition (True/False): true
# Eligible for Exam

# %%
#9
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest =", a)
elif b >= a and b >= c:
    print("Largest =", b)
else:
    print("Largest =", c)

if a == b == c:
    print("All numbers are equal")
else:
    print("Not all equal")

if a < b and b < c:
    print("Strictly Increasing Order")
else:
    print("Not in Increasing Order")
# Out:
# Enter first number: 2
# Enter second number: 3
# Enter third number: 4
# Largest = 4
# Not all equal
# Strictly Increasing Order

# %%
#10
burger = int(input("Enter number of burgers: "))
pizza = int(input("Enter number of pizzas: "))

bill = burger * 120 + pizza * 250
items = burger + pizza

if items >= 5:
    bill = bill - (bill * 10 / 100)

if bill >= 1000:
    bill = bill - (bill * 5 / 100)

print("Final Bill = ₹", bill)
# Out:
# Enter number of burgers: 4
# Enter number of pizzas: 2
# Final Bill = ₹ 882.0
